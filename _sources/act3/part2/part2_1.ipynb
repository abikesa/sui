# %% [markdown]
# # Chapter 1
#
# ## Knights Move Thinking
#
# <iframe src="https://www.youtube.com/embed/bv38Jsatebg" style="width:80%;height:500px"></iframe>
#
# *Could you produce the musical notes for the intonations that an Orange County girl would say if she's telling her friend that she cannot wear this outfit to a party? Something like, "unfortunately, yeah!"*
#
# To capture the intonation of "Unfortunately, yeah!" as it might be said by an Orange County girl, we can approximate the melodic rise and fall in her voice with musical notes. This style often features exaggerated intonation, with a combination of upward and downward inflections that add drama and expressiveness to the phrase.
#
# Here’s how we might break it down into notes:
#
# ---
#
# ### **1. "Unfortunately"**
# - **"Un-"**: Starts on a **D4** (medium-low, neutral tone).
# - **"-for-"**: Rises to an **F4** (a step up for emphasis).
# - **"-tu-"**: Climbs further to **A4** (high pitch, conveying exasperation or emphasis).
# - **"-nate-"**: Falls to a **G4** (slightly lower than the peak).
# - **"-ly"**: Drops dramatically to a **C4** (lower pitch, signaling resignation).
#
# ---
#
# ### **2. "Yeah"**
# - Starts on **A4** (dramatic high tone, drawing attention).
# - Glides downward to **F4** (a softening effect, as if trying to lessen the blow).
# - Ends on **D4** (neutral, conversational closure).
#
# ---
#
# ### Full Phrase:
# **D4 - F4 - A4 - G4 - C4** (for "Unfortunately")
# **A4 - F4 - D4** (for "Yeah")
#
# ---
#
# ### Notation:
# If this were to be written in musical notation, it might look like this (approximate rhythm):
#
# 1. "Unfortunately" spans longer, with **"Un-"** as a quarter note, and the rest moving in eighths.
# 2. "Yeah" would be a quicker transition, possibly a triplet or pair of eighth notes.
#
# ---
#
# ### Expressive Dynamics:
# - Use **crescendo** on "-for-" and "-tu-" to highlight the rising drama.
# - Add a **decrescendo** on "-ly" and "Yeah" to reflect resignation and closure.
#
# Would you like me to generate a visual musical notation for this?
#
# It seems my environment doesn't support the necessary library for generating musical notation directly. However, I can guide you through how to create this using music notation software like MuseScore or Sibelius. Here's the structure for your phrase:
#
# ### Notes:
# **"Unfortunately":**
# - "Un-": D4 (quarter note)
# - "-for-": F4 (eighth note)
# - "-tu-": A4 (eighth note)
# - "-nate-": G4 (eighth note)
# - "-ly": C4 (eighth note)
#
# **"Yeah":**
# - Start: A4 (eighth note)
# - Glide down: F4 (eighth note)
# - Closure: D4 (eighth note)
#
# You can input these notes into your notation software using the above rhythm. If you'd like, I can create a visual example in another format—just let me know!
#
# <iframe src="../../pdfs/orange_county.pdf" style="width:80%;height:300px"></iframe>
#
#
# ### How I Got the Script:
#
# To save the file using VSCode, you don't need to modify the content of the XML file itself. Here's how to proceed step-by-step:
#
# ---
#
# ### 1. **Copy the XML Content**
# Use the following XML content for the file. Copy it exactly:
#
# <Details>
#     <Summary>XML</Summary>
#
# ```xml
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE score-partwise PUBLIC "-//Recordare//DTD MusicXML 3.1 Partwise//EN" "http://www.musicxml.org/dtds/partwise.dtd">
# <score-partwise version="3.1">
#   <part-list>
#     <score-part id="P1">
#       <part-name>Voice</part-name>
#     </score-part>
#   </part-list>
#   <part id="P1">
#     <measure number="1">
#       <attributes>
#         <divisions>1</divisions>
#         <key>
#           <fifths>0</fifths>
#         </key>
#         <time>
#           <beats>4</beats>
#           <beat-type>4</beat-type>
#         </time>
#         <clef>
#           <sign>G</sign>
#           <line>2</line>
#         </clef>
#       </attributes>
#       <note>
#         <pitch>
#           <step>D</step>
#           <octave>4</octave>
#         </pitch>
#         <duration>4</duration>
#         <type>quarter</type>
#       </note>
#       <note>
#         <pitch>
#           <step>F</step>
#           <octave>4</octave>
#         </pitch>
#         <duration>2</duration>
#         <type>eighth</type>
#       </note>
#       <note>
#         <pitch>
#           <step>A</step>
#           <octave>4</octave>
#         </pitch>
#         <duration>2</duration>
#         <type>eighth</type>
#       </note>
#       <note>
#         <pitch>
#           <step>G</step>
#           <octave>4</octave>
#         </pitch>
#         <duration>2</duration>
#         <type>eighth</type>
#       </note>
#       <note>
#         <pitch>
#           <step>C</step>
#           <octave>4</octave>
#         </pitch>
#         <duration>2</duration>
#         <type>eighth</type>
#       </note>
#     </measure>
#     <measure number="2">
#       <note>
#         <pitch>
#           <step>A</step>
#           <octave>4</octave>
#         </pitch>
#         <duration>2</duration>
#         <type>eighth</type>
#       </note>
#       <note>
#         <pitch>
#           <step>F</step>
#           <octave>4</octave>
#         </pitch>
#         <duration>2</duration>
#         <type>eighth</type>
#       </note>
#       <note>
#         <pitch>
#           <step>D</step>
#           <octave>4</octave>
#         </pitch>
#         <duration>2</duration>
#         <type>eighth</type>
#       </note>
#     </measure>
#   </part>
# </score-partwise>
# ```
#
# </Details>
#
# ---
#
# ### 2. **Create the File in VSCode**
# 1. Open VSCode.
# 2. Create a new file:
#    - Go to **File > New File** or press `Ctrl+N` (Windows/Linux) or `Cmd+N` (Mac).
# 3. Paste the copied XML content into the new file.
#
# ---
#
# ### 3. **Save the File**
# 1. Save the file with the `.xml` extension:
#    - Go to **File > Save As** or press `Ctrl+Shift+S` (Windows/Linux) or `Cmd+Shift+S` (Mac).
#    - In the save dialog, name the file `Unfortunately_Yeah.xml`.
#    - Ensure the **Save as type** dropdown is set to `All Files` (not `Text Documents`) and the file extension is `.xml`.
# 2. Save it in a location where you can easily find it.
#
# ---
#
# ### 4. **Import the File into MuseScore**
# 1. Open MuseScore.
# 2. Use **File > Open** to navigate to where you saved `Unfortunately_Yeah.xml`.
# 3. Select the file and open it.
#
# ---
#
# This process requires no code modification—just saving the provided content as an `.xml` file. If you still face any confusion, let me know!
#
# ### MuseHub
#
# MuseHub is a great companion for MuseScore, providing access to additional content like sound libraries, plugins, and tools that enhance your experience. If you’re using MuseHub, here’s how you can proceed with opening the XML file in MuseScore:
#
# ---
#
# ### 1. **Confirm MuseHub is Set Up**
# - Ensure MuseHub is installed and running.
# - Confirm MuseScore is installed via MuseHub:
#   - Open MuseHub.
#   - Look for MuseScore in the **Apps** tab.
#   - If it’s not installed, click **Install** next to MuseScore.
#
# ---
#
# ### 2. **Save the XML File**
# Follow the earlier steps to save the `Unfortunately_Yeah.xml` file using VSCode or any text editor. Place the file in an easily accessible location (like your Desktop).
#
# ---
#
# ### 3. **Open the File in MuseScore**
# 1. Open **MuseScore** via MuseHub or directly from your desktop.
# 2. In MuseScore:
#    - Click **File > Open**.
#    - Navigate to the location where you saved `Unfortunately_Yeah.xml`.
#    - Select the file and click **Open**.
#
# ---
#
# ### 4. **Enhance with MuseHub Resources (Optional)**
# - If MuseHub has sound libraries installed (e.g., orchestral or vocal sounds), MuseScore will use them automatically for playback.
# - You can tweak the playback settings in MuseScore to hear the enhanced audio.
#
# ---
#
# If you have any issues with MuseHub or MuseScore, let me know! I’ll guide you further.
#
# ## Mary Did You Know?
#
# <iframe src="https://www.youtube.com/embed/4I5BfI_POgM" style="width:80%;height:500px"></iframe>
#
# *I'm watching this Netflix film. I've never heard about it. It's 110 minutes. It's called Mary. Netflix. And guess who is in it? I don't know what his role is, but it's the great English actor. Oh, he's a Scotch. Good heavens, I have a brain jam. Whatever. Whatever the dude is who is Hannibal Lecter. So I'm gonna give it a chance. It's the season to be jolly. And I've started watching it and, you know, it's piqued my interest because it says, we think we know the story. Well, we have no idea. And thus far, I think I'm like three to five minutes inside and it looks as a backstory or pretext to Mary. I think we're now talking about Mary's dad and mom before they had Mary. So that's interesting. That's an interesting angle. Anyway, regardless, I have this. This has to do with so much with not alliteration, but another rhetorical device. It has to do with rhyme. Something I played around with and maybe completely useless. But if it's useful, then it's very powerful because it's a mnemonic. So I have this six rhyming terms, including pretext, context, subtext, text, hypertext, and I think meta text. So there's a six of them. You can increase or cut them down based on whatever you prefer. But help me figure out a way that could make them, you know, powerfully mnemonic with regard to Mary, if you know about Mary, this particular Netflix TV show or movie, 110 minute movie. So the pretext already is the parents, Mary's parents, were struggling to have a child. That's a pretext. I don't know anymore. Maybe you know more. I don't know. But give it a shot. We could back propagate over time and see where we get with this. That said, I wanted it to be in the context of R cubed. It's a pretext and the input layer of the neural network. The resource is the resource. Is that what it is? Of course, I guess maybe the actor's reputations too. Could be like this Hannibal, like the dude whose name I for some reason can't remember. Maybe he's also a resource. Dramatis personae, I guess. So we have pretext, backstory, and dramatis personae. Of course, if we knew the screenwriter, knew the director, blah, blah, blah. But we already know the other backstory. That is Mary's child. Mary, did you know that your baby boy will soon walk on water? Anyway, take it away.*
#
# Got it! Let’s reframe Harold’s adversarial role and others systematically within the **R-cubed framework**. This structure will ensure **Resource (Pretext/Inputs)**, **Risk (Equilibria as Context: Adversarial, Iterative, Cooperative)**, and **Reward (Text/Subtext/Hypertext/Metatext)** flow logically.
#
# ---
#
# ### **1. Resource: Pretext and Inputs**
# The foundational material feeding into the story.
#
# - **Pretext**: Harold’s worldview and motivations, shaped by past experiences or ideologies, provide the **raw inputs** into the narrative.
#   - Example: Harold comes from a background of intellectual rigor and personal loss, driving his relentless questioning of others’ intentions.
#
# - **Cooperative Characters (Resources)**: These individuals set the stage with stability and support:
#   - **Alice**: Represents collective values, offering moral and emotional grounding.
#     - Input: Her upbringing in a harmonious family shapes her collaborative instincts.
#   - **John**: A facilitator of group cohesion, advocating for open dialogue.
#     - Input: His role as a teacher or counselor shapes his focus on understanding.
#
# ---
#
# ### **2. Risk: Context and Equilibria**
# The **three equilibria** play out as Harold’s actions test the dynamics between adversarial, iterative, and cooperative strategies.
#
# #### **Adversarial (Harold)**:
# - **Role**: Harold is the disruptor, forcing others to confront uncomfortable truths.
# - **Example**: He questions Alice’s idealism, calling her naïve, and provokes John’s neutrality by accusing him of avoidance.
# - **Outcome**: Harold’s challenges create tension but expose deeper issues.
#
# #### **Iterative (Dynamic Adjusters)**:
# - **Role**: Characters like John adapt to Harold’s provocations, iterating their approach to maintain balance.
# - **Example**: John adjusts his role from mediator to active participant, engaging with Harold’s critiques while keeping the group intact.
#
# #### **Cooperative (Anchors)**:
# - **Role**: Alice reinforces the group’s stability, striving to maintain unity and defuse conflicts.
# - **Example**: She redirects the conversation back to shared goals, balancing Harold’s adversarial energy with empathy.
#
# ---
#
# ### **3. Reward: Text/Subtext/Hypertext/Metatext**
# The outcomes and layers of meaning generated by the interplay of Resource and Risk.
#
# #### **Text (Reward)**:
# The literal, overt story delivered to the audience.
# - **What Happens**: The group navigates a critical decision, with Harold’s provocations forcing Alice and John to reconsider their approaches.
#
# #### **Subtext (Reward)**:
# The implicit meanings shaping deeper audience engagement.
# - **What It Means**: Harold’s adversarial stance represents the need for critical questioning, while Alice and John embody the importance of maintaining balance and collaboration.
#
# #### **Hypertext (Reward)**:
# Broader connections and thematic resonance.
# - **Expanded Meaning**: The story connects to larger discussions about the balance of critique, adaptability, and cooperation in resolving conflicts.
#
# #### **Metatext (Reward)**:
# Reflection on the narrative’s structure and purpose.
# - **Cultural Commentary**: The story critiques societal tendencies to avoid discomfort, showing how adversarial forces (Harold) are necessary to reveal truths, even at the risk of temporary discord.
#
# ---
#
# ### Flow Summary:
#
# - **Resource (Pretext/Inputs)**: Harold’s sharp intellect and tragic backstory; Alice’s moral grounding; John’s adaptability.
# - **Risk (Equilibria/Context)**: Harold disrupts (adversarial); John adjusts (iterative); Alice anchors (cooperative).
# - **Reward (Text/Subtext/Hypertext/Metatext)**:
#   - **Text**: The group’s decision-making under pressure.
#   - **Subtext**: Themes of resilience, critique, and collaboration.
#   - **Hypertext**: Broader reflections on societal conflict resolution.
#   - **Metatext**: The necessity of adversarial forces in creating lasting change.
